# %%
# VARIABLES
# nombre_variable = valor
# CREAR VARIABLES
numero = 5
decimal = -8.5
texto = "Luis"
verdadero = True
falso = False

# %%
# USAR VARIABLES
print(numero)
texto
# Out:
# 5
# 'Luis'

# %%
# TUPLAS
tuplas = (1,2,3,4)
tuplas
# Out:
# (1, 2, 3, 4)

# %%
# CONJUNTOS - SETS
conjuntos = {"hola","que","tal","que","tal"}
conjuntos
# Out:
# {'hola', 'que', 'tal'}

# %%
# ESTRUCTURAS DE DATOS
# LISTA
lista = ["Hola","que","tal"]
lista[0] #Notación de slicing
# Out:
# 'Hola'

# %%
# DICCIONARIOS
diccionario = {0:"Hola",1:"que",2:"tal","Luis":6556655665}
diccionario["Luis"]
# Out:
# 6556655665

# %%
lista_numeros = [655655656,9565665656]
agenda = {"Luis":lista_numeros,"pepe":98944665655,"Juan":656556656565}
agenda["Luis"][1]
# Out:
# 9565665656

# %%
str1 = 'Me gusta Python'
str1[0]
# Out:
# 'M'

# %%
str1 = ['Me', 'gusta', 'Python']
str1[2]
# Out:
# 'Python'

# %%
# OPERADORES
# OPERADORES ARITMETICOS
6 + 2
9 - 2
9 * 2
9 / 2
9 // 2
9 % 2
9 ** 5

# OPERADOR DE ASIGNACIÓN
# nombre_variable = valor

# OPERADORES DE COMPARACIÓN
var1 = 9
var2 = "9"
var1 == var2
var1 != var2
var1 > 2
var1 < 2
var1 >= 2
var1 <= 2
var1 in [1,2,3,4,9,5]
# Out:
# True

# %%
# CONDICIONALES
nuestra_velocidad = 100
maxima_velocidad = 120
if nuestra_velocidad < maxima_velocidad:
  print("Todo OK")
elif nuestra_velocidad == maxima_velocidad:
  print("Deja de acelerar")
else:
  print("Multita")
# Out:
# Todo OK
# Multita

# %%
# 1º ESTADO: Indefinido
# patata
# 2ºESTADO: Nulo
# Variable creada, no tipo, no contenido
patata = None
# 3º ESTADO
# Variable creada, sí tipo, no contenido
lista = []
numero = 0
decimales = 0.0
falso = False
texto = ""
# 4º ESTADO
# Variable creada, sí tipo, sí contenido
lista = [1,2,3]
numero = 5
decimales = 0.00000001
texto = " Hola"
verdadero = True

# %%
lista = [0]

if lista:
  print("Lista llena")
else:
  print("Lista vacía")
# Out:
# Lista llena
